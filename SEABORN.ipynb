# %% [markdown]
# <a href="https://colab.research.google.com/github/Edwinshajan2006/data-science-/blob/main/SEABORN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **USING ONLY SEABORN**

# %%
import seaborn as sns
import pandas as pd

# %%
sns.__version__
# Out:
# '0.13.2'

# %%
df=pd.read_excel('/content/weather_visualization_dataset.xlsx')
df.head()
# Out:
#    record_id       city month  temperature_c  humidity  rainfall_mm  \
# 0          1    Kolkata   Sep             24        61          208
# 1          2  Bengaluru   May             18        90          108
# 2          3      Delhi   Jun             23        45           93
# 3          4      Delhi   May             34        63          150
# 4          5    Kolkata   Jul             21        43          118
#
#    wind_speed_kmph  air_quality_index  visibility_km weather_type
# 0               15                224             13       Stormy
# 1               32                202              6        Rainy
# 2               15                 58             14        Rainy
# 3                9                 66              1       Cloudy
# 4               29                195             12       Cloudy

# %%
#Q1
sns.histplot(x='city', y='temperature_c', data=df)
plt.show()

# %%
#Q2
sns.barplot(x='city', y='temperature_c', data=df)
plt.show()

# %%
#Q 3

sns.scatterplot(x='humidity', y='temperature_c', data=df)
plt.show()

# %%
#Q 4 A

sns.barplot(x='rainfall_mm', y='month', data=df)
plt.show()

# %%
#Q 4 B

sns.lineplot(x='month',y='rainfall_mm',data=df)
# Out:
# <Axes: xlabel='month', ylabel='rainfall_mm'>

# %%
#Q 4 C

sns.barplot(data=df,
            x='month',
            y='rainfall_mm')
# Out:
# <Axes: xlabel='month', ylabel='rainfall_mm'>

# %%
monthly_rainfall = df.groupby('month')['rainfall_mm'].mean().reset_index()

# %%
monthly_rainfall
# Out:
#   month  rainfall_mm
# 0   Apr   138.086957
# 1   Aug   162.166667
# 2   Feb   102.583333
# 3   Jan   128.625000
# 4   Jul   151.576923
# 5   Jun   158.782609
# 6   Mar   124.500000
# 7   May   118.833333
# 8   Oct   134.904762
# 9   Sep   125.260870

# %%
#Q5
sns.scatterplot(x='month', y='city',hue='air_quality_index', data=df)
plt.show()

# %%
#Q6 a
sns.histplot(x='weather_type', y='wind_speed_kmph', data=df)
plt.show()

# %%
#Q 6 B

sns.barplot( x='weather_type',
             y='wind_speed_kmph',
             data=df)
# Out:
# <Axes: xlabel='weather_type', ylabel='wind_speed_kmph'>

# %%
#6 c
sns.histplot(df['wind_speed_kmph'],bins=20)
plt.show()

# %%
#q 7
sns.countplot(x='weather_type',data=df)
plt.show()

# %%
#q 8 a
# Out:
# <Axes: xlabel='rainfall_mm', ylabel='visibility_km'>

# %%
#8 b
sns.lineplot(x='rainfall_mm',y='visibility_km',data=df)
plt.show()

# %%
#8 c
sns.violinplot(x='rainfall_mm',y='visibility_km',data=df)
plt.show()

# %%
#q9
sns.pairplot(df[['temperature_c','humidity','wind_speed_kmph']])
plt.show()
