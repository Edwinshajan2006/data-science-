# %% [markdown]
# <a href="https://colab.research.google.com/github/Edwinshajan2006/data-science-/blob/main/fuctions%20using%20numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
#importing numpy

# %%
import pandas as pd
#importing panda

# %%
data=pd.read_excel("/content/numpy_sales_dataset 1.xlsx")
#to link excel to the program inside the brackets we are giving the location path

# %%
data.head()
#to read the starting 5 rows
# Out:
#    order_id region    product  units_sold  unit_price  discount  revenue  \
# 0         1   West      Phone           6        2999         0    17994
# 1         2   East      Phone          83        2113        10   175379
# 2         3  North     Tablet          14        1826        10    25564
# 3         4   East  Accessory          62        3377        10   209374
# 4         5   East      Phone          58         861        15    49938
#
#    profit month  rating
# 0   14076   Jun       1
# 1  170710   Mar       3
# 2   21134   Feb       3
# 3  205901   Feb       4
# 4   45446   Feb       3

# %%
data.tail()
#to read the last 5 rows;
# Out:
#     order_id region    product  units_sold  unit_price  discount  revenue  \
# 45        46  South     Laptop          70        4433         0   310310
# 46        47  South     Tablet          65        3180         5   206700
# 47        48  North      Phone          61        4137         0   252357
# 48        49  South  Accessory           8        4434        15    35472
# 49        50  South      Phone          25        2629         5    65725
#
#     profit month  rating
# 45  307384   Feb       5
# 46  202332   Jan       2
# 47  249311   Feb       3
# 48   32762   Jun       2
# 49   61723   Jun       4

# %%
col = ["order_id","units_sold","unit_price","discount","revenue","profit","rating"] #storing numberical columns
num_array=data[col].to_numpy() #converting numerical array to numpy

#key error found via execution

# %%
num_array
#all the outputs without headings
# Out:
# array([[     1,      6,   2999,      0,  17994,  14076,      1],
#        [     2,     83,   2113,     10, 175379, 170710,      3],
#        [     3,     14,   1826,     10,  25564,  21134,      3],
#        [     4,     62,   3377,     10, 209374, 205901,      4],
#        [     5,     58,    861,     15,  49938,  45446,      3],
#        [     6,     43,   3222,      5, 138546, 134662,      4],
#        [     7,     29,   4190,     15, 121510, 117649,      1],
#        [     8,     30,   2352,      0,  70560,  67946,      1],
#        [     9,     35,   4021,     15, 140735, 138301,      3],
#        [    10,     89,   3478,      5, 309542, 305131,      1],
#        [    11,     86,   1749,     10, 150414, 146247,      5],
#        [    12,     59,   1674,     15,  98766,  97996,      3],
#        [    13,     39,   4334,     10, 169026, 167644,      4],
#        [    14,     65,   2490,     10, 161850, 159121,      3],
#        [    15,     64,   3436,      0, 219904, 215675,      4],
#        [    16,     69,   4135,     15, 285315, 282779,      4],
#        [    17,     64,    938,      0,  60032,  55143,      2],
#        [    18,     46,   1832,     10,  84272,  82853,      3],
#        [    19,      8,   4234,     15,  33872,  31267,      4],
#        [    20,      5,   1935,      5,   9675,   5760,      2],
#        [    21,     41,   1104,      0,  45264,  42695,      5],
#        [    22,     72,   3963,     10, 285336, 280467,      1],
#        [    23,     38,   2043,     10,  77634,  75142,      4],
#        [    24,     46,   1673,      5,  76958,  74292,      3],
#        [    25,     64,   2134,      0, 136576, 135261,      2],
#        [    26,     52,   4877,     15, 253604, 250528,      3],
#        [    27,     21,   1678,      0,  35238,  32348,      1],
#        [    28,     52,   2767,      5, 143884, 143069,      2],
#        [    29,      5,   3397,      5,  16985,  16308,      1],
#        [    30,     12,   3675,      0,  44100,  40722,      2],
#        [    31,     56,   1827,     10, 102312,  99542,      3],
#        [    32,     56,   2364,     10, 132384, 130823,      5],
#        [    33,     47,   3658,      5, 171926, 169456,      3],
#        [    34,     86,   3462,     15, 297732, 295476,      1],
#        [    35,     95,   1238,     15, 117610, 115796,      1],
#        [    36,     38,   3272,     10, 124336, 120978,      1],
#        [    37,     81,   3682,     10, 298242, 296864,      2],
#        [    38,     70,   2019,     10, 141330, 136496,      4],
#        [    39,     42,   2982,     10, 125244, 122982,      5],
#        [    40,     64,   2613,     15, 167232, 163931,      1],
#        [    41,     93,    827,      5,  76911,  73488,      2],
#        [    42,     11,   1026,     10,  11286,   8988,      1],
#        [    43,     11,   2507,     10,  27577,  23404,      4],
#        [    44,     70,   1931,      5, 135170, 131243,      5],
#        [    45,     49,    654,     10,  32046,  28951,      1],
#        [    46,     70,   4433,      0, 310310, 307384,      5],
#        [    47,     65,   3180,      5, 206700, 202332,      2],
#        [    48,     61,   4137,      0, 252357, 249311,      3],
#        [    49,      8,   4434,     15,  35472,  32762,      2],
#        [    50,     25,   2629,      5,  65725,  61723,      4]])

# %%
#2 a
num_array.shape
# Out:
# (50, 7)

# %%
#2 b
num_array.ndim
# Out:
# 2

# %%
#2 c
num_array.dtype
# Out:
# dtype('int64')

# %%
#3 a
units_sold=['units_sold']
units_sold_array=data[units_sold].to_numpy()
units_sold_array
# Out:
# array([[ 6],
#        [83],
#        [14],
#        [62],
#        [58],
#        [43],
#        [29],
#        [30],
#        [35],
#        [89],
#        [86],
#        [59],
#        [39],
#        [65],
#        [64],
#        [69],
#        [64],
#        [46],
#        [ 8],
#        [ 5],
#        [41],
#        [72],
#        [38],
#        [46],
#        [64],
#        [52],
#        [21],
#        [52],
#        [ 5],
#        [12],
#        [56],
#        [56],
#        [47],
#        [86],
#        [95],
#        [38],
#        [81],
#        [70],
#        [42],
#        [64],
#        [93],
#        [11],
#        [11],
#        [70],
#        [49],
#        [70],
#        [65],
#        [61],
#        [ 8],
#        [25]])

# %%
#3 b
unit_price=['unit_price']
unit_price_array=data[unit_price].to_numpy()
unit_price_array
# Out:
# array([[2999],
#        [2113],
#        [1826],
#        [3377],
#        [ 861],
#        [3222],
#        [4190],
#        [2352],
#        [4021],
#        [3478],
#        [1749],
#        [1674],
#        [4334],
#        [2490],
#        [3436],
#        [4135],
#        [ 938],
#        [1832],
#        [4234],
#        [1935],
#        [1104],
#        [3963],
#        [2043],
#        [1673],
#        [2134],
#        [4877],
#        [1678],
#        [2767],
#        [3397],
#        [3675],
#        [1827],
#        [2364],
#        [3658],
#        [3462],
#        [1238],
#        [3272],
#        [3682],
#        [2019],
#        [2982],
#        [2613],
#        [ 827],
#        [1026],
#        [2507],
#        [1931],
#        [ 654],
#        [4433],
#        [3180],
#        [4137],
#        [4434],
#        [2629]])

# %%
#4 a

sum_units_sold=np.sum(units_sold_array)
sum_units_sold
# Out:
# np.int64(2455)

# %%
#4 b
avg_units_sold=np.mean(units_sold_array)
avg_units_sold
# Out:
# np.float64(49.1)

# %%
#4 c a
min_units_sold=np.min(units_sold_array)
min_units_sold
# Out:
# np.int64(5)

# %%
# 4 c b
max_units_sold=np.max(units_sold_array)
max_units_sold
# Out:
# np.int64(95)

# %%
#5
total_profit=['profit']
unit_price_array=data[total_profit].to_numpy()
unit_price_array
# Out:
# array([[ 14076],
#        [170710],
#        [ 21134],
#        [205901],
#        [ 45446],
#        [134662],
#        [117649],
#        [ 67946],
#        [138301],
#        [305131],
#        [146247],
#        [ 97996],
#        [167644],
#        [159121],
#        [215675],
#        [282779],
#        [ 55143],
#        [ 82853],
#        [ 31267],
#        [  5760],
#        [ 42695],
#        [280467],
#        [ 75142],
#        [ 74292],
#        [135261],
#        [250528],
#        [ 32348],
#        [143069],
#        [ 16308],
#        [ 40722],
#        [ 99542],
#        [130823],
#        [169456],
#        [295476],
#        [115796],
#        [120978],
#        [296864],
#        [136496],
#        [122982],
#        [163931],
#        [ 73488],
#        [  8988],
#        [ 23404],
#        [131243],
#        [ 28951],
#        [307384],
#        [202332],
#        [249311],
#        [ 32762],
#        [ 61723]])

# %%
#5 b

total_profit=np.sum(unit_price_array)
total_profit
# Out:
# np.int64(6328203)

# %%
#5 A (defining )
total_revenue=['revenue']
unit_revenue_array=data[total_revenue].to_numpy()
unit_revenue_array
# Out:
# array([[ 17994],
#        [175379],
#        [ 25564],
#        [209374],
#        [ 49938],
#        [138546],
#        [121510],
#        [ 70560],
#        [140735],
#        [309542],
#        [150414],
#        [ 98766],
#        [169026],
#        [161850],
#        [219904],
#        [285315],
#        [ 60032],
#        [ 84272],
#        [ 33872],
#        [  9675],
#        [ 45264],
#        [285336],
#        [ 77634],
#        [ 76958],
#        [136576],
#        [253604],
#        [ 35238],
#        [143884],
#        [ 16985],
#        [ 44100],
#        [102312],
#        [132384],
#        [171926],
#        [297732],
#        [117610],
#        [124336],
#        [298242],
#        [141330],
#        [125244],
#        [167232],
#        [ 76911],
#        [ 11286],
#        [ 27577],
#        [135170],
#        [ 32046],
#        [310310],
#        [206700],
#        [252357],
#        [ 35472],
#        [ 65725]])

# %%
#5 a
total_revenue_array=np.sum(unit_revenue_array)
total_revenue_array
# Out:
# np.int64(6479749)

# %%
#Q6
num_array[:10:1]
# Out:
# array([[     1,      6,   2999,      0,  17994,  14076,      1],
#        [     2,     83,   2113,     10, 175379, 170710,      3],
#        [     3,     14,   1826,     10,  25564,  21134,      3],
#        [     4,     62,   3377,     10, 209374, 205901,      4],
#        [     5,     58,    861,     15,  49938,  45446,      3],
#        [     6,     43,   3222,      5, 138546, 134662,      4],
#        [     7,     29,   4190,     15, 121510, 117649,      1],
#        [     8,     30,   2352,      0,  70560,  67946,      1],
#        [     9,     35,   4021,     15, 140735, 138301,      3],
#        [    10,     89,   3478,      5, 309542, 305131,      1]])

# %%
#Q6 B
num_array[50:44:-1]
# Out:
# array([[    50,     25,   2629,      5,  65725,  61723,      4],
#        [    49,      8,   4434,     15,  35472,  32762,      2],
#        [    48,     61,   4137,      0, 252357, 249311,      3],
#        [    47,     65,   3180,      5, 206700, 202332,      2],
#        [    46,     70,   4433,      0, 310310, 307384,      5]])

# %%
#Q7
units_sold_array[units_sold_array>avg_units_sold]
# Out:
# array([83, 62, 58, 89, 86, 59, 65, 64, 69, 64, 72, 64, 52, 52, 56, 56, 86,
#        95, 81, 70, 64, 93, 70, 70, 65, 61])

# %%
#size confirmation before reshaping
num_array.size
# Out:
# 350

# %%
#Q8 a
num_array.shape
# Out:
# (50, 7)

# %%
#Q8 b reshaping
num_array.reshape(7,50)
# Out:
# array([[     1,      6,   2999,      0,  17994,  14076,      1,      2,
#             83,   2113,     10, 175379, 170710,      3,      3,     14,
#           1826,     10,  25564,  21134,      3,      4,     62,   3377,
#             10, 209374, 205901,      4,      5,     58,    861,     15,
#          49938,  45446,      3,      6,     43,   3222,      5, 138546,
#         134662,      4,      7,     29,   4190,     15, 121510, 117649,
#              1,      8],
#        [    30,   2352,      0,  70560,  67946,      1,      9,     35,
#           4021,     15, 140735, 138301,      3,     10,     89,   3478,
#              5, 309542, 305131,      1,     11,     86,   1749,     10,
#         150414, 146247,      5,     12,     59,   1674,     15,  98766,
#          97996,      3,     13,     39,   4334,     10, 169026, 167644,
#              4,     14,     65,   2490,     10, 161850, 159121,      3,
#             15,     64],
#        [  3436,      0, 219904, 215675,      4,     16,     69,   4135,
#             15, 285315, 282779,      4,     17,     64,    938,      0,
#          60032,  55143,      2,     18,     46,   1832,     10,  84272,
#          82853,      3,     19,      8,   4234,     15,  33872,  31267,
#              4,     20,      5,   1935,      5,   9675,   5760,      2,
#             21,     41,   1104,      0,  45264,  42695,      5,     22,
#             72,   3963],
#        [    10, 285336, 280467,      1,     23,     38,   2043,     10,
#          77634,  75142,      4,     24,     46,   1673,      5,  76958,
#          74292,      3,     25,     64,   2134,      0, 136576, 135261,
#              2,     26,     52,   4877,     15, 253604, 250528,      3,
#             27,     21,   1678,      0,  35238,  32348,      1,     28,
#             52,   2767,      5, 143884, 143069,      2,     29,      5,
#           3397,      5],
#        [ 16985,  16308,      1,     30,     12,   3675,      0,  44100,
#          40722,      2,     31,     56,   1827,     10, 102312,  99542,
#              3,     32,     56,   2364,     10, 132384, 130823,      5,
#             33,     47,   3658,      5, 171926, 169456,      3,     34,
#             86,   3462,     15, 297732, 295476,      1,     35,     95,
#           1238,     15, 117610, 115796,      1,     36,     38,   3272,
#             10, 124336],
#        [120978,      1,     37,     81,   3682,     10, 298242, 296864,
#              2,     38,     70,   2019,     10, 141330, 136496,      4,
#             39,     42,   2982,     10, 125244, 122982,      5,     40,
#             64,   2613,     15, 167232, 163931,      1,     41,     93,
#            827,      5,  76911,  73488,      2,     42,     11,   1026,
#             10,  11286,   8988,      1,     43,     11,   2507,     10,
#          27577,  23404],
#        [     4,     44,     70,   1931,      5, 135170, 131243,      5,
#             45,     49,    654,     10,  32046,  28951,      1,     46,
#             70,   4433,      0, 310310, 307384,      5,     47,     65,
#           3180,      5, 206700, 202332,      2,     48,     61,   4137,
#              0, 252357, 249311,      3,     49,      8,   4434,     15,
#          35472,  32762,      2,     50,     25,   2629,      5,  65725,
#          61723,      4]])

# %%
#Q C
#size same after reshaping
num_array.size
# Out:
# 350

# %%
#Q9 a step
discount_sale=['discount']
discount_sale1=data[discount_sale].to_numpy()
discount_sale1
# Out:
# array([[ 0],
#        [10],
#        [10],
#        [10],
#        [15],
#        [ 5],
#        [15],
#        [ 0],
#        [15],
#        [ 5],
#        [10],
#        [15],
#        [10],
#        [10],
#        [ 0],
#        [15],
#        [ 0],
#        [10],
#        [15],
#        [ 5],
#        [ 0],
#        [10],
#        [10],
#        [ 5],
#        [ 0],
#        [15],
#        [ 0],
#        [ 5],
#        [ 5],
#        [ 0],
#        [10],
#        [10],
#        [ 5],
#        [15],
#        [15],
#        [10],
#        [10],
#        [10],
#        [10],
#        [15],
#        [ 5],
#        [10],
#        [10],
#        [ 5],
#        [10],
#        [ 0],
#        [ 5],
#        [ 0],
#        [15],
#        [ 5]])

# %%
#9 a

disc=discount_sale1/100
disc
# Out:
# array([[0.  ],
#        [0.1 ],
#        [0.1 ],
#        [0.1 ],
#        [0.15],
#        [0.05],
#        [0.15],
#        [0.  ],
#        [0.15],
#        [0.05],
#        [0.1 ],
#        [0.15],
#        [0.1 ],
#        [0.1 ],
#        [0.  ],
#        [0.15],
#        [0.  ],
#        [0.1 ],
#        [0.15],
#        [0.05],
#        [0.  ],
#        [0.1 ],
#        [0.1 ],
#        [0.05],
#        [0.  ],
#        [0.15],
#        [0.  ],
#        [0.05],
#        [0.05],
#        [0.  ],
#        [0.1 ],
#        [0.1 ],
#        [0.05],
#        [0.15],
#        [0.15],
#        [0.1 ],
#        [0.1 ],
#        [0.1 ],
#        [0.1 ],
#        [0.15],
#        [0.05],
#        [0.1 ],
#        [0.1 ],
#        [0.05],
#        [0.1 ],
#        [0.  ],
#        [0.05],
#        [0.  ],
#        [0.15],
#        [0.05]])

# %%
#9 B
after_disc=unit_revenue_array*disc
after_disc
# Out:
# array([[    0.  ],
#        [17537.9 ],
#        [ 2556.4 ],
#        [20937.4 ],
#        [ 7490.7 ],
#        [ 6927.3 ],
#        [18226.5 ],
#        [    0.  ],
#        [21110.25],
#        [15477.1 ],
#        [15041.4 ],
#        [14814.9 ],
#        [16902.6 ],
#        [16185.  ],
#        [    0.  ],
#        [42797.25],
#        [    0.  ],
#        [ 8427.2 ],
#        [ 5080.8 ],
#        [  483.75],
#        [    0.  ],
#        [28533.6 ],
#        [ 7763.4 ],
#        [ 3847.9 ],
#        [    0.  ],
#        [38040.6 ],
#        [    0.  ],
#        [ 7194.2 ],
#        [  849.25],
#        [    0.  ],
#        [10231.2 ],
#        [13238.4 ],
#        [ 8596.3 ],
#        [44659.8 ],
#        [17641.5 ],
#        [12433.6 ],
#        [29824.2 ],
#        [14133.  ],
#        [12524.4 ],
#        [25084.8 ],
#        [ 3845.55],
#        [ 1128.6 ],
#        [ 2757.7 ],
#        [ 6758.5 ],
#        [ 3204.6 ],
#        [    0.  ],
#        [10335.  ],
#        [    0.  ],
#        [ 5320.8 ],
#        [ 3286.25]])

# %%
rev_after_disc=unit_revenue_array-after_disc
rev_after_disc
# Out:
# array([[ 17994.  ],
#        [157841.1 ],
#        [ 23007.6 ],
#        [188436.6 ],
#        [ 42447.3 ],
#        [131618.7 ],
#        [103283.5 ],
#        [ 70560.  ],
#        [119624.75],
#        [294064.9 ],
#        [135372.6 ],
#        [ 83951.1 ],
#        [152123.4 ],
#        [145665.  ],
#        [219904.  ],
#        [242517.75],
#        [ 60032.  ],
#        [ 75844.8 ],
#        [ 28791.2 ],
#        [  9191.25],
#        [ 45264.  ],
#        [256802.4 ],
#        [ 69870.6 ],
#        [ 73110.1 ],
#        [136576.  ],
#        [215563.4 ],
#        [ 35238.  ],
#        [136689.8 ],
#        [ 16135.75],
#        [ 44100.  ],
#        [ 92080.8 ],
#        [119145.6 ],
#        [163329.7 ],
#        [253072.2 ],
#        [ 99968.5 ],
#        [111902.4 ],
#        [268417.8 ],
#        [127197.  ],
#        [112719.6 ],
#        [142147.2 ],
#        [ 73065.45],
#        [ 10157.4 ],
#        [ 24819.3 ],
#        [128411.5 ],
#        [ 28841.4 ],
#        [310310.  ],
#        [196365.  ],
#        [252357.  ],
#        [ 30151.2 ],
#        [ 62438.75]])

# %%
#9 C
rev_after_disc.sum()
# Out:
# np.float64(5938519.4)

# %%
#Q10
sorted_profits = np.sort(unit_price_array, axis=None)[::-1]
top_5_profits = sorted_profits[:5]

top_5_profits
# Out:
# array([307384, 305131, 296864, 295476, 282779])
